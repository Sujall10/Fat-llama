# %%
import pandas as pd

# %%
df = pd.read_csv("churn_finall.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       1340 non-null   int64
#  1   name                          1340 non-null   object
#  2   gender                        1340 non-null   object
#  3   age                           1340 non-null   int64
#  4   email                         1340 non-null   object
#  5   phone_number                  1340 non-null   int64
#  6   location_id                   1340 non-null   int64
#  7   preferred_services            1340 non-null   object
#  8   preferred_time_slots          1340 non-null   object
#  9   booking_history_count         1340 non-null   int64
#  10  cancellation_rate             1340 non-null   float64
#  11  average_rating_given          1340 non-null   float64
# ...

# %%
df
# Out:
#       user_id              name  gender  age                        email  \
# 0           0         Roy Braun    male   21          roy.braun@yahoo.com
# 1           1    Joseph Holsten    male   37   joseph.holsten@company.com
# 2           2     Wilma Mcinnis  female   48    wilma.mcinnis@company.com
# 3           3      Paula Daniel  female   23       paula.daniel@yahoo.com
# 4           4   Patricia Carson  female   44  patricia.carson@outlook.com
# ...       ...               ...     ...  ...                          ...
# 1335     1335  Albert Garroutte    male   23   albert.garroutte@gmail.com
# 1336     1336        Kim Shores  female   40       kim.shores@company.com
# 1337     1337     James Gimenez    male   28      james.gimenez@gmail.com
# 1338     1338      Viola Agosta  female   52       viola.agosta@yahoo.com
# 1339     1339    Paul Rodriguez    male   35     paul.rodriguez@yahoo.com
#
#       phone_number  location_id preferred_services preferred_time_slots  \
# ...

# %%
df_loc = pd.read_csv("LocationCityFinal.csv")
df_loc
# Out:
#     Location ID           City                                     State
# 0             1  Visakhapatnam                            Andhra Pradesh
# 1             2     Vijayawada                            Andhra Pradesh
# 2             3         Guntur                            Andhra Pradesh
# 3             4        Nellore                            Andhra Pradesh
# 4             5       Itanagar                         Arunachal Pradesh
# ..          ...            ...                                       ...
# 95           96      Kavaratti                               Lakshadweep
# 96           97      Baramulla                         Jammu and Kashmir
# 97           98       Srinagar                         Jammu and Kashmir
# 98           99          Daman  Dadra and Nagar Haveli and Daman and Diu
# 99          100       Silvassa  Dadra and Nagar Haveli and Daman and Diu
#
# [100 rows x 3 columns]

# %%
df_loc[df_loc['State']=='Gujarat']
# Out:
#     Location ID         City    State
# 18           19    Ahmedabad  Gujarat
# 19           20        Surat  Gujarat
# 20           21     Vadodara  Gujarat
# 21           22  Gandhinagar  Gujarat
# 22           23       Rajkot  Gujarat

# %%
df_loc['State'].value_counts()
# Out:
# State
# Gujarat                                     5
# Andhra Pradesh                              4
# Bihar                                       4
# Uttar Pradesh                               4
# Haryana                                     4
# Karnataka                                   4
# Tamil Nadu                                  4
# Madhya Pradesh                              4
# Punjab                                      3
# West Bengal                                 3
# Uttarakhand                                 3
# Tripura                                     3
# Telangana                                   3
# Rajasthan                                   3
# Odisha                                      3
# Goa                                         3
# Assam                                       3
# Maharashtra                                 3
# Kerala                                      3
# Jharkhand                                   3
# ...

# %%
df_users = pd.read_csv("Users (1).csv")
df_users
# Out:
#        Unnamed: 0  user_id                 name  \
# 0               0    17925     Bahadurjit Chana
# 1               1     2417     Anthony Majumdar
# 2               2    18104        Turvi Krishna
# 3               3     3058         Bhavani Shah
# 4               4     1537         Vritti Barad
# ...           ...      ...                  ...
# 29995       29995    19443        Qasim Narayan
# 29996       29996    18310     Jeevika Deshmukh
# 29997       29997    27629  Brinda Balakrishnan
# 29998       29998    19955       Tarak Sachdeva
# 29999       29999      293            Osha Suri
#
#                                       email  phone_number date_joined  \
# 0         bahadurjit.chana17925@example.com  919116582730  2024-11-23
# 1          anthony.majumdar2417@example.com  918467940366  2023-09-03
# 2            turvi.krishna18104@example.com  919722782465  2023-02-05
# 3              bhavani.shah3058@example.com  917369995285  2022-03-30
# ...

# %%
df_users = df_users.drop(columns=['Unnamed: 0'])

# %%
df_users = df_users.sort_values('user_id')
df_users
# Out:
#        user_id            name                            email  phone_number  \
# 14753        1    Isaac Bakshi        isaac.bakshi1@example.com  916043321819
# 21251        2      Anvi Konda          anvi.konda2@example.com  916013389083
# 6462         3     Udant Dewan         udant.dewan3@example.com  917794026542
# 3622         4    Harsh Chahal        harsh.chahal4@example.com  918116155940
# 20850        5     Pahal Balay         pahal.balay5@example.com  916618495931
# ...        ...             ...                              ...           ...
# 13103    29996   Gautami Tella   gautami.tella29996@example.com  916627464974
# 12106    29997   Tripti Minhas   tripti.minhas29997@example.com  916077665355
# 6966     29998  Nachiket Sarma  nachiket.sarma29998@example.com  916189795035
# 26328    29999     Nirja Kanda     nirja.kanda29999@example.com  918984944302
# 28870    30000        Ekani Om        ekani.om30000@example.com  918539946494
#
# ...

# %%
User = df_users.copy().reset_index(drop=True)
User
# Out:
#        user_id            name                            email  phone_number  \
# 0            1    Isaac Bakshi        isaac.bakshi1@example.com  916043321819
# 1            2      Anvi Konda          anvi.konda2@example.com  916013389083
# 2            3     Udant Dewan         udant.dewan3@example.com  917794026542
# 3            4    Harsh Chahal        harsh.chahal4@example.com  918116155940
# 4            5     Pahal Balay         pahal.balay5@example.com  916618495931
# ...        ...             ...                              ...           ...
# 29995    29996   Gautami Tella   gautami.tella29996@example.com  916627464974
# 29996    29997   Tripti Minhas   tripti.minhas29997@example.com  916077665355
# 29997    29998  Nachiket Sarma  nachiket.sarma29998@example.com  916189795035
# 29998    29999     Nirja Kanda     nirja.kanda29999@example.com  918984944302
# 29999    30000        Ekani Om        ekani.om30000@example.com  918539946494
#
# ...

# %%
User['user_type'].value_counts()
# Out:
# user_type
# rental      14971
# provider     8956
# both         6073
# Name: count, dtype: int64

# %%
Provider = User[User['user_type'] != 'rental']
Provider
# Out:
#        user_id              name                            email  \
# 0            1      Isaac Bakshi        isaac.bakshi1@example.com
# 1            2        Anvi Konda          anvi.konda2@example.com
# 2            3       Udant Dewan         udant.dewan3@example.com
# 3            4      Harsh Chahal        harsh.chahal4@example.com
# 5            6  Ayushman Chander    ayushman.chander6@example.com
# ...        ...               ...                              ...
# 29989    29990     Gabriel Gopal   gabriel.gopal29990@example.com
# 29990    29991     Shivansh Bora   shivansh.bora29991@example.com
# 29993    29994    Qarin Varghese  qarin.varghese29994@example.com
# 29996    29997     Tripti Minhas   tripti.minhas29997@example.com
# 29998    29999       Nirja Kanda     nirja.kanda29999@example.com
#
#        phone_number date_joined        city  location_id user_type
# 0      916043321819  2024-05-14   Kozhikode           49  provider
# ...

# %%
Renters = User[User['user_type'] != 'provider']

# %%
Renters
# Out:
#        user_id             name                             email  \
# 2            3      Udant Dewan          udant.dewan3@example.com
# 3            4     Harsh Chahal         harsh.chahal4@example.com
# 4            5      Pahal Balay          pahal.balay5@example.com
# 6            7       Tejas Kaul           tejas.kaul7@example.com
# 7            8    Yashasvi Bala        yashasvi.bala8@example.com
# ...        ...              ...                               ...
# 29993    29994   Qarin Varghese   qarin.varghese29994@example.com
# 29994    29995  Warjas Dhaliwal  warjas.dhaliwal29995@example.com
# 29995    29996    Gautami Tella    gautami.tella29996@example.com
# 29997    29998   Nachiket Sarma   nachiket.sarma29998@example.com
# 29999    30000         Ekani Om         ekani.om30000@example.com
#
#        phone_number date_joined           city  location_id user_type
# 2      917794026542  2023-03-17         Panaji           23      both
# ...

# %%
Provider = Provider.sort_values('date_joined')

# %%
Provider['Provider_ID'] = range(1, len(Provider)+1)

# %%
Provider
# Out:
#        user_id               name                               email  \
# 3259      3260       Bhavani Nagi        bhavani.nagi3260@example.com
# 28289    28290  Alka Ramachandran  alka.ramachandran28290@example.com
# 1772      1773      Jeevika Barad       jeevika.barad1773@example.com
# 7659      7660       Upasna Baria        upasna.baria7660@example.com
# 12710    12711        Waida Kakar        waida.kakar12711@example.com
# ...        ...                ...                                 ...
# 13381    13382        Nikita Bath        nikita.bath13382@example.com
# 11670    11671         Riya Madan         riya.madan11671@example.com
# 20464    20465        Yasti Kanda        yasti.kanda20465@example.com
# 21044    21045     Theodore Sagar     theodore.sagar21045@example.com
# 14126    14127     Veer Nagarajan     veer.nagarajan14127@example.com
#
#        phone_number date_joined         city  location_id user_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       1340 non-null   int64
#  1   name                          1340 non-null   object
#  2   gender                        1340 non-null   object
#  3   age                           1340 non-null   int64
#  4   email                         1340 non-null   object
#  5   phone_number                  1340 non-null   int64
#  6   location_id                   1340 non-null   int64
#  7   preferred_services            1340 non-null   object
#  8   preferred_time_slots          1340 non-null   object
#  9   booking_history_count         1340 non-null   int64
#  10  cancellation_rate             1340 non-null   float64
#  11  average_rating_given          1340 non-null   float64
# ...

# %%
df['Customer_Support_Contacts'].max()
# Out:
# 19

# %%
Provider.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15029 entries, 3259 to 14126
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       15029 non-null  int64
#  1   name          15029 non-null  object
#  2   email         15029 non-null  object
#  3   phone_number  15029 non-null  int64
#  4   date_joined   15029 non-null  object
#  5   city          15029 non-null  object
#  6   location_id   15029 non-null  int64
#  7   user_type     15029 non-null  object
#  8   Provider_ID   15029 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.1+ MB

# %%
Provider['location_id'].value_counts()
# Out:
# location_id
# 43    260
# 83    245
# 45    234
# 57    187
# 22    185
#      ...
# 36    113
# 51    109
# 52    106
# 64     90
# 81     81
# Name: count, Length: 100, dtype: int64

# %%
df_provider = pd.read_csv('Provider.csv')
df_provider
# Out:
#        provider_id  user_id  location_id  cancellation_rate  response_time
# 0                1     3058            1               7.34           37.4
# 1                2    10294            1               5.30           44.2
# 2                3      650            1              14.09            1.0
# 3                4    27041            1               8.81           67.8
# 4                5    13128            1              17.06           41.3
# ...            ...      ...          ...                ...            ...
# 15024        15025    14471          100               5.34           54.2
# 15025        15026    19443          100               0.00           36.0
# 15026        15027    27629          100               8.86           57.2
# 15027        15028    19955          100               3.75           52.7
# 15028        15029      293          100               6.15           48.6
#
# [15029 rows x 5 columns]

# %%
df_provider['location_id'].value_counts()
# Out:
# location_id
# 43    260
# 83    245
# 45    234
# 57    187
# 22    185
#      ...
# 36    113
# 51    109
# 52    106
# 64     90
# 81     81
# Name: count, Length: 100, dtype: int64

# %%
items = pd.read_csv("Items.csv")
items
# Out:
#                   category          subcategory  Provider_ID     ITEM_ID  \
# 0         Books and Sports        Gym & Fitness         6260  ITEM000001
# 1      Commercial Vehicles  Commercial Vehicles         6660  ITEM000002
# 2         Books and Sports        Gym & Fitness        13263  ITEM000003
# 3                     Cars                 Cars         2902  ITEM000004
# 4         Books and Sports     Sports Equipment        10699  ITEM000005
# ...                    ...                  ...          ...         ...
# 39995                 Cars                 Cars         3057  ITEM039996
# 39996     Books and Sports     Sports Equipment        11390  ITEM039997
# 39997            Furniture     Beds & Wardrobes         7863  ITEM039998
# 39998              Mobiles          Accessories         2770  ITEM039999
# 39999                Bikes          Motorcycles         5611  ITEM040000
#
#                                         title  \
# ...

# %%
items['title'].value_counts()
# Out:
# title
# Maruti Swift ZXi Plus                    915
# Tata Nexon EV Max                        850
# Mahindra Bolero Pikup                    841
# MG Hector Plus Sharp                     830
# Honda City ZX CVT                        823
#                                         ...
# Sony BRAVIA XR A80L 65-inch OLED          64
# Ninja Foodi 5-in-1 Indoor Grill           64
# Sigma 85mm f/1.4 DG DN Art Lens           64
# Dell XPS 15 9530                          62
# Samsung Family Hub Smart Refrigerator     62
# Name: count, Length: 180, dtype: int64

# %%
a = items[items['title'] == 'Maruti Swift ZXi Plus']

# %%
a['Provider_ID'].value_counts()
# Out:
# Provider_ID
# 14774    3
# 8705     2
# 8130     2
# 6754     2
# 14363    2
#         ..
# 2065     1
# 13046    1
# 11715    1
# 1482     1
# 9341     1
# Name: count, Length: 896, dtype: int64

# %%
a[a['Provider_ID'] == 14774]
# Out:
#       category subcategory  Provider_ID     ITEM_ID                  title  \
# 9249      Cars        Cars        14774  ITEM009250  Maruti Swift ZXi Plus
# 20442     Cars        Cars        14774  ITEM020443  Maruti Swift ZXi Plus
# 24730     Cars        Cars        14774  ITEM024731  Maruti Swift ZXi Plus
#
#                                              description  price_per_day
# 9249   Sporty hatchback with 1.2L DualJet engine, aut...          25717
# 20442  Sporty hatchback with 1.2L DualJet engine, aut...          10458
# 24730  Sporty hatchback with 1.2L DualJet engine, aut...          12300

# %%
a[a['Provider_ID'] == 8705]
# Out:
#       category subcategory  Provider_ID     ITEM_ID                  title  \
# 26169     Cars        Cars         8705  ITEM026170  Maruti Swift ZXi Plus
# 27175     Cars        Cars         8705  ITEM027176  Maruti Swift ZXi Plus
#
#                                              description  price_per_day
# 26169  Sporty hatchback with 1.2L DualJet engine, aut...          15951
# 27175  Sporty hatchback with 1.2L DualJet engine, aut...          24301

# %%
df_Final_items = pd.read_csv("Final_items.csv")
df_Final_items
# Out:
#                   category          subcategory     item_id  provider_id  \
# 0                    Bikes          Motorcycles  ITEM000001         5326
# 1      Commercial Vehicles  Commercial Vehicles  ITEM000002        10905
# 2                  Mobiles        Mobile Phones  ITEM000003         4676
# 3                    Bikes             Bicycles  ITEM000004         2939
# 4                    Bikes             Bicycles  ITEM000005         2649
# ...                    ...                  ...         ...          ...
# 39995                 Cars                 Cars  ITEM039996         1923
# 39996                 Cars                 Cars  ITEM039997         5410
# 39997                 Cars                 Cars  ITEM039998         4348
# 39998  Commercial Vehicles  Commercial Vehicles  ITEM039999        14445
# 39999              Fashion                  Men  ITEM040000         5677
#
#                                       title  \
# 0      Harley-Davidson Street Glide Special
# ...

# %%
df_User_detail = pd.read_csv("User_details.csv")
df_User_detail
# Out:
#        user_id                 name                                 email  \
# 0        17925     Bahadurjit Chana     bahadurjit.chana17925@example.com
# 1         2417     Anthony Majumdar      anthony.majumdar2417@example.com
# 2        18104        Turvi Krishna        turvi.krishna18104@example.com
# 3         3058         Bhavani Shah          bhavani.shah3058@example.com
# 4         1537         Vritti Barad          vritti.barad1537@example.com
# ...        ...                  ...                                   ...
# 29995    19443        Qasim Narayan        qasim.narayan19443@example.com
# 29996    18310     Jeevika Deshmukh     jeevika.deshmukh18310@example.com
# 29997    27629  Brinda Balakrishnan  brinda.balakrishnan27629@example.com
# 29998    19955       Tarak Sachdeva       tarak.sachdeva19955@example.com
# 29999      293            Osha Suri              osha.suri293@example.com
#
#        phone_number date_joined      city  location_id user_type  age  gender
# ...

# %%
Lenders = pd.read_csv('Provider.csv')
Lenders
# Out:
#        provider_id  user_id  location_id  cancellation_rate  response_time
# 0                1     3058            1               7.34           37.4
# 1                2    10294            1               5.30           44.2
# 2                3      650            1              14.09            1.0
# 3                4    27041            1               8.81           67.8
# 4                5    13128            1              17.06           41.3
# ...            ...      ...          ...                ...            ...
# 15024        15025    14471          100               5.34           54.2
# 15025        15026    19443          100               0.00           36.0
# 15026        15027    27629          100               8.86           57.2
# 15027        15028    19955          100               3.75           52.7
# 15028        15029      293          100               6.15           48.6
#
# [15029 rows x 5 columns]

# %%
# Lenders = df_User_detail[df_User_detail['user_type'] != 'rental']
# Lenders = Lender.sort_values('date_joined')
# Out:
#        user_id                 name                                 email  \
# 3         3058         Bhavani Shah          bhavani.shah3058@example.com
# 6        10294        Nicholas Dara        nicholas.dara10294@example.com
# 8          650       Chavvi Maharaj         chavvi.maharaj650@example.com
# 9        27041   Ekansh Swaminathan   ekansh.swaminathan27041@example.com
# 13       13128          Azaan Batra          azaan.batra13128@example.com
# ...        ...                  ...                                   ...
# 29994    14471         Mason Khalsa         mason.khalsa14471@example.com
# 29995    19443        Qasim Narayan        qasim.narayan19443@example.com
# 29997    27629  Brinda Balakrishnan  brinda.balakrishnan27629@example.com
# 29998    19955       Tarak Sachdeva       tarak.sachdeva19955@example.com
# 29999      293            Osha Suri              osha.suri293@example.com
#
#        phone_number date_joined      city  location_id user_type  age  gender
# ...

# %%
loc_map = Lenders.set_index('provider_id')['location_id']
df_Final_items['location_id'] = df_Final_items['provider_id'].map(loc_map)
df_Final_items
# Out:
#                   category          subcategory     item_id  provider_id  \
# 0                    Bikes          Motorcycles  ITEM000001         5326
# 1      Commercial Vehicles  Commercial Vehicles  ITEM000002        10905
# 2                  Mobiles        Mobile Phones  ITEM000003         4676
# 3                    Bikes             Bicycles  ITEM000004         2939
# 4                    Bikes             Bicycles  ITEM000005         2649
# ...                    ...                  ...         ...          ...
# 39995                 Cars                 Cars  ITEM039996         1923
# 39996                 Cars                 Cars  ITEM039997         5410
# 39997                 Cars                 Cars  ITEM039998         4348
# 39998  Commercial Vehicles  Commercial Vehicles  ITEM039999        14445
# 39999              Fashion                  Men  ITEM040000         5677
#
#                                       title  \
# 0      Harley-Davidson Street Glide Special
# ...

# %%
Lenders[Lenders['provider_id'] == 5326]
# Out:
#       provider_id  user_id  location_id  cancellation_rate  response_time
# 5325         5326     9582           37               9.23           55.6

# %%
a = df_Final_items[df_Final_items['location_id'] == 37]
a
# Out:
#                        category          subcategory     item_id  provider_id  \
# 0                         Bikes          Motorcycles  ITEM000001         5326
# 6                          Cars                 Cars  ITEM000007         5342
# 128            Books and Sports     Sports Equipment  ITEM000129         5369
# 217                     Mobiles          Accessories  ITEM000218         5341
# 393                       Bikes             Bicycles  ITEM000394         5341
# ...                         ...                  ...         ...          ...
# 39348                   Mobiles              Tablets  ITEM039349         5289
# 39384       Commercial Vehicles  Commercial Vehicles  ITEM039385         5352
# 39525                   Fashion                  Men  ITEM039526         5260
# 39561                      Cars                 Cars  ITEM039562         5296
# 39954  Electronics & Appliances  Printers & Monitors  ITEM039955         5299
#
# ...

# %%
a['provider_id'].value_counts()
# Out:
# provider_id
# 5334    7
# 5355    6
# 5341    6
# 5281    6
# 5256    5
#        ..
# 5252    1
# 5332    1
# 5279    1
# 5306    1
# 5364    1
# Name: count, Length: 121, dtype: int64

# %%
a[a['provider_id'] == 5334]
# Out:
#                        category          subcategory     item_id  provider_id  \
# 4653                      Bikes          Motorcycles  ITEM004654         5334
# 9819   Electronics & Appliances              Fridges  ITEM009820         5334
# 20203                     Bikes          Motorcycles  ITEM020204         5334
# 22189          Books and Sports     Sports Equipment  ITEM022190         5334
# 29039  Electronics & Appliances              Fridges  ITEM029040         5334
# 32947       Commercial Vehicles  Commercial Vehicles  ITEM032948         5334
# 37499                      Cars                 Cars  ITEM037500         5334
#
#                                           title  \
# 4653       Harley-Davidson Street Glide Special
# 9819   Bosch Series 6 Side-by-Side Refrigerator
# 20203                   BMW R 1250 GS Adventure
# 22189       Wilson Pro Staff RF97 Tennis Racket
# 29039      Godrej Edge Pro Quantum Refrigerator
# 32947                         Tata Ace Gold CNG
# ...

# %%
df_Final_items
# Out:
#                   category          subcategory     item_id  provider_id  \
# 0                    Bikes          Motorcycles  ITEM000001         5326
# 1      Commercial Vehicles  Commercial Vehicles  ITEM000002        10905
# 2                  Mobiles        Mobile Phones  ITEM000003         4676
# 3                    Bikes             Bicycles  ITEM000004         2939
# 4                    Bikes             Bicycles  ITEM000005         2649
# ...                    ...                  ...         ...          ...
# 39995                 Cars                 Cars  ITEM039996         1923
# 39996                 Cars                 Cars  ITEM039997         5410
# 39997                 Cars                 Cars  ITEM039998         4348
# 39998  Commercial Vehicles  Commercial Vehicles  ITEM039999        14445
# 39999              Fashion                  Men  ITEM040000         5677
#
#                                       title  \
# 0      Harley-Davidson Street Glide Special
# ...

# %%
df_User_detail
# Out:
#        user_id                 name                                 email  \
# 0        17925     Bahadurjit Chana     bahadurjit.chana17925@example.com
# 1         2417     Anthony Majumdar      anthony.majumdar2417@example.com
# 2        18104        Turvi Krishna        turvi.krishna18104@example.com
# 3         3058         Bhavani Shah          bhavani.shah3058@example.com
# 4         1537         Vritti Barad          vritti.barad1537@example.com
# ...        ...                  ...                                   ...
# 29995    19443        Qasim Narayan        qasim.narayan19443@example.com
# 29996    18310     Jeevika Deshmukh     jeevika.deshmukh18310@example.com
# 29997    27629  Brinda Balakrishnan  brinda.balakrishnan27629@example.com
# 29998    19955       Tarak Sachdeva       tarak.sachdeva19955@example.com
# 29999      293            Osha Suri              osha.suri293@example.com
#
#        phone_number date_joined      city  location_id user_type  age  gender
# ...

# %%
Renters = df_User_detail[df_User_detail['user_type'] != 'provider']
Renters
# Out:
#        user_id              name                              email  \
# 0        17925  Bahadurjit Chana  bahadurjit.chana17925@example.com
# 1         2417  Anthony Majumdar   anthony.majumdar2417@example.com
# 2        18104     Turvi Krishna     turvi.krishna18104@example.com
# 3         3058      Bhavani Shah       bhavani.shah3058@example.com
# 4         1537      Vritti Barad       vritti.barad1537@example.com
# ...        ...               ...                                ...
# 29991    15134     Anirudh Divan     anirudh.divan15134@example.com
# 29992    26835  Yashodhara Naidu  yashodhara.naidu26835@example.com
# 29993    19876      Dakshesh Ram      dakshesh.ram19876@example.com
# 29994    14471      Mason Khalsa      mason.khalsa14471@example.com
# 29996    18310  Jeevika Deshmukh  jeevika.deshmukh18310@example.com
#
#        phone_number date_joined      city  location_id user_type  age  gender
# ...

# %%
df_Final_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       40000 non-null  object
#  1   subcategory    40000 non-null  object
#  2   item_id        40000 non-null  object
#  3   provider_id    40000 non-null  int64
#  4   title          40000 non-null  object
#  5   description    40000 non-null  object
#  6   price_per_day  40000 non-null  float64
#  7   location_id    40000 non-null  int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.4+ MB

# %%
Lenders.tail(30)
# Out:
#        provider_id  user_id  location_id  cancellation_rate  response_time
# 14999        15000    16989          100               5.92           49.7
# 15000        15001     7141          100               7.66           64.1
# 15001        15002     6694          100              12.64           31.3
# 15002        15003     6447          100              10.20           43.9
# 15003        15004     4533          100               9.90           49.6
# 15004        15005     5799          100               1.97           65.6
# 15005        15006    17137          100              25.00           52.8
# 15006        15007    25368          100               8.96           36.3
# 15007        15008    24144          100               7.92           49.8
# 15008        15009     1452          100               3.89           73.7
# 15009        15010     6225          100               1.59           34.0
# ...

# %%
df_Final_items[df_Final_items['provider_id']==15000]
# Out:
#                        category       subcategory     item_id  provider_id  \
# 26208  Electronics & Appliances  Cameras & Lenses  ITEM026209        15000
#
#                                        title  \
# 26208  Fujifilm X100V Premium Compact Camera
#
#                                              description  price_per_day  \
# 26208  Fixed-lens street photography camera with X-Tr...         3012.0
#
#        location_id
# 26208          100

# %%
df_Final_items.to_csv('Itemsss', index=False)

# %%
Renters.to_csv("Rentersss" , index= False)

# %%
df_provider.to_csv("Providerrr" , index=False)

# %%
# Reduce the scale for performance — sample a subset
sampled_renters = valid_renters.sample(n=100, random_state=42)  # Sample 100 renters
sampled_items = items_df.sample(n=300, random_state=42)         # Sample 300 items

# Reset tracking structures
bookings = []
used_dates = {}
booking_id = 1

for _, renter in Renters.iterrows():
    renter_location = renter['location_id']

    if renter['user_type'] == 'both':
        provider_ids = providers_df[
            (providers_df['location_id'] == renter_location) &
            (providers_df['user_id'] != renter['user_id'])
        ]['provider_id']
    else:
        provider_ids = providers_df[
            providers_df['location_id'] == renter_location
        ]['provider_id']

    available_items = sampled_items[
        (sampled_items['location_id'] == renter_location) &
        (sampled_items['provider_id'].isin(provider_ids))
    ]

    # Attempt to create up to 2 bookings per user
    for item in available_items.sample(n=min(2, len(available_items)), random_state=42).itertuples():
        item_id = item.item_id
        if item_id not in used_dates:
            used_dates[item_id] = []

        tries = 0
        while tries < 5:
            start = random_date(today - timedelta(days=180), today - timedelta(days=10))
            end = start + timedelta(days=random.randint(1, 7))
            if all(e < start or s > end for s, e in used_dates[item_id]):
                used_dates[item_id].append((start, end))
                bookings.append({
                    'booking_id': booking_id,
                    'user_id': renter['user_id'],
                    'item_id': item_id,
                    'provider_id': item.provider_id,
                    'start_date': start.date(),
                    'end_date': end.date()
                })
                booking_id += 1
                break
            tries += 1

bookings_df = pd.DataFrame(bookings)
bookings_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 2
#       1 # Reduce the scale for performance — sample a subset
# ----> 2 sampled_renters = valid_renters.sample(n=100, random_state=42)  # Sample 100 renters
#       3 sampled_items = items_df.sample(n=300, random_state=42)         # Sample 300 items
#       5 # Reset tracking structures
#
# NameError: name 'valid_renters' is not defined

# %%
# Limit number of bookings per renter to speed up
# Avg_booking_count = (4,13)
import random

# Clear previous data
bookings = []
used_dates = {}
booking_id = 1

# Shuffle renters
valid_renters = Renters.sample(frac=1, random_state=42)

for _, renter in valid_renters.iterrows():
    location_items = df_Final_items[df_Final_items['location_id'] == renter['location_id']]
    # continue your logic here...


    if renter['user_type'] == 'both':
        provider_ids = df_provider[
            (df_provider['location_id'] == renter['location_id']) &
            (df_provider['user_id'] != renter['user_id'])
        ]['provider_id']
    else:
        provider_ids = df_provider[
            df_provider['location_id'] == renter['location_id']
        ]['provider_id']

    available_items = location_items[location_items['provider_id'].isin(provider_ids)]
    available_items = available_items.sample(frac=1, random_state=42)

    renter_booking_count = 0

    for _, item in available_items.iterrows():
        MAX_BOOKINGS_PER_RENTER = random.randint(4, 13)
        if renter_booking_count >= MAX_BOOKINGS_PER_RENTER:
            break

        item_id = item['item_id']
        if item_id not in used_dates:
            used_dates[item_id] = []

        tries = 0
        while tries < 5:
            start = random_date(today - timedelta(days=180), today - timedelta(days=1))
            end = start + timedelta(days=random.randint(1, 10))
            if all(e < start or s > end for s, e in used_dates[item_id]):
                used_dates[item_id].append((start, end))
                bookings.append({
                    'booking_id': booking_id,
                    'user_id': renter['user_id'],
                    'item_id': item_id,
                    'provider_id': item['provider_id'],
                    'start_date': start.date(),
                    'end_date': end.date()
                })
                booking_id += 1
                renter_booking_count += 1
                break
            tries += 1

# Final DataFrame
bookings_df = pd.DataFrame(bookings)
bookings_df.head()
# Out:
#    booking_id  user_id     item_id  provider_id  start_date    end_date
# 0           1    28238  ITEM007287        10331  2025-01-20  2025-01-26
# 1           2    28238  ITEM027903        10340  2025-01-22  2025-02-01
# 2           3    28238  ITEM025385        10380  2025-01-25  2025-02-03
# 3           4    28238  ITEM005249        10385  2025-02-04  2025-02-08
# 4           5    28238  ITEM039651        10402  2024-11-22  2024-12-01

# %%
import random
from datetime import datetime, timedelta

# Function to generate a random date between two dates
def random_date(start, end):
    delta = end - start
    int_delta = delta.days
    random_days = random.randint(0, int_delta)
    return start + timedelta(days=random_days)

# Also set today for reference
today = datetime.today()

# %%
bookings_df
# Out:
#         booking_id  user_id     item_id  provider_id  start_date    end_date
# 0                1    28238  ITEM007287        10331  2025-01-20  2025-01-26
# 1                2    28238  ITEM027903        10340  2025-01-22  2025-02-01
# 2                3    28238  ITEM025385        10380  2025-01-25  2025-02-03
# 3                4    28238  ITEM005249        10385  2025-02-04  2025-02-08
# 4                5    28238  ITEM039651        10402  2024-11-22  2024-12-01
# ...            ...      ...         ...          ...         ...         ...
# 135136      135137    20744  ITEM033514        11342  2024-11-13  2024-11-23
# 135137      135138    20744  ITEM031351        11270  2025-03-27  2025-03-30
# 135138      135139    20744  ITEM034079        11325  2025-01-01  2025-01-04
# 135139      135140    20744  ITEM036137        11307  2025-01-24  2025-01-25
# 135140      135141    20744  ITEM036903        11290  2024-11-01  2024-11-05
#
# [135141 rows x 6 columns]

# %%
df_User_detail[df_User_detail['user_id'] == 28238]
# Out:
#        user_id        name                        email  phone_number  \
# 20719    28238  Qabil Sant  qabil.sant28238@example.com  917663841702
#
#       date_joined      city  location_id user_type  age gender
# 20719  2023-04-08  Rourkela           70      both   30   male

# %%
df_provider[df_provider['provider_id'] == 10331]
# Out:
#        provider_id  user_id  location_id  cancellation_rate  response_time
# 10330        10331      211           70               3.36           27.5

# %%
bookings_df[bookings_df['item_id']=='ITEM025385']
# Out:
#        booking_id  user_id     item_id  provider_id  start_date    end_date
# 2               3    28238  ITEM025385        10380  2025-01-19  2025-01-28
# 6913         6914    10296  ITEM025385        10380  2025-01-31  2025-02-10
# 16564       16565     3133  ITEM025385        10380  2025-02-26  2025-03-08
# 43397       43398     6339  ITEM025385        10380  2024-11-25  2024-11-26
# 62471       62472    29174  ITEM025385        10380  2024-11-29  2024-12-05

# %%
bookings_df[bookings_df['user_id'] == 56]
# Out:
#        booking_id  user_id     item_id  provider_id  start_date    end_date
# 10589       10590       56  ITEM005077         1235  2025-01-01  2025-01-07
# 10590       10591       56  ITEM017040         1247  2024-11-15  2024-11-18
# 10591       10592       56  ITEM005084         1201  2025-03-29  2025-04-05
# 10592       10593       56  ITEM033179         1161  2024-12-19  2024-12-29
# 10593       10594       56  ITEM027330         1212  2025-03-18  2025-03-27

# %%
bookings_df.to_csv('bookings_df.csv')

# %%
bookings_df['user_id'].nunique()
# Out:
# 21044

# %%
x = bookings_df['user_id'].value_counts()

# %%
x = pd.DataFrame(x)

# %%
x['count'].value_counts()
# Out:
# count
# 6     4591
# 5     4329
# 7     3962
# 8     2811
# 4     2757
# 9     1577
# 10     740
# 11     225
# 12      44
# 13       8
# Name: count, dtype: int64

# %%
bookings_df['start_date']
# Out:
# start_date
# 2024-10-11    1440
# 2024-10-12    1160
# 2025-04-08    1047
# 2024-10-13     942
# 2025-04-07     890
#               ...
# 2024-12-02     694
# 2025-03-26     691
# 2025-03-11     685
# 2024-12-06     683
# 2025-01-11     663
# Name: count, Length: 180, dtype: int64

# %%
# bookings_df
bookings_df[bookings_df['start_date'] == bookings_df['end_date']]
# Out:
# Empty DataFrame
# Columns: [booking_id, user_id, item_id, provider_id, start_date, end_date]
# Index: []

# %%
bookings_df.to_csv("bookingss.csv", index=False)

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# # Load your dataset
bookings_dff = pd.read_csv("bookingss.csv", parse_dates=["start_date", "end_date"])

# Shuffle to randomize
bookings_dff = bookings_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Split into 25% short and 75% long bookings
short_count = int(0.25 * len(bookings_df))
long_count = len(bookings_df) - short_count

short_bookings = bookings_df.iloc[:short_count]
long_bookings = bookings_df.iloc[short_count:]

# Keep track of used times for each item to avoid overlap
used_times = {}

def get_non_overlapping_time(item_id, duration):
    for _ in range(100):  # max 100 tries
        start = datetime.now() - timedelta(days=random.randint(1, 180), hours=random.randint(0, 23))
        end = start + duration

        if item_id not in used_times:
            used_times[item_id] = []

        overlap = any(s < end and e > start for s, e in used_times[item_id])
        if not overlap:
            used_times[item_id].append((start, end))
            return start, end
    return None, None  # fallback

# Update short bookings (<24h)
for i, row in short_bookings.iterrows():
    duration = timedelta(hours=random.uniform(1, 23))
    start, end = get_non_overlapping_time(row['item_id'], duration)
    short_bookings.at[i, 'start_date'] = start
    short_bookings.at[i, 'end_date'] = end

# Update long bookings (>24h)
for i, row in long_bookings.iterrows():
    duration = timedelta(days=random.randint(2, 10))
    start, end = get_non_overlapping_time(row['item_id'], duration)
    long_bookings.at[i, 'start_date'] = start
    long_bookings.at[i, 'end_date'] = end

# Combine all and save
final_df = pd.concat([short_bookings, long_bookings]).sort_values("start_date")
# final_df.to_csv("bookings_updated.csv", index=False)

# %%
import random
from datetime import datetime, timedelta
import pandas as pd

# Clear previous data
bookings = []
used_dates = {}
booking_id = 1

# Shuffle renters
valid_renters = Renters.sample(frac=1, random_state=42)

# Reference date
today = datetime.today()

def get_non_overlapping_time(item_id, duration):
    for _ in range(10):  # Try 10 times to avoid infinite loops
        start = today - timedelta(days=random.randint(1, 180), hours=random.randint(0, 23))
        end = start + duration

        if item_id not in used_dates:
            used_dates[item_id] = []

        overlap = any(s < end and e > start for s, e in used_dates[item_id])
        if not overlap:
            used_dates[item_id].append((start, end))
            return start, end
    return None, None  # if no non-overlapping slot is found

for _, renter in valid_renters.iterrows():
    location_items = df_Final_items[df_Final_items['location_id'] == renter['location_id']]

    if renter['user_type'] == 'both':
        provider_ids = df_provider[
            (df_provider['location_id'] == renter['location_id']) &
            (df_provider['user_id'] != renter['user_id'])
        ]['provider_id']
    else:
        provider_ids = df_provider[
            df_provider['location_id'] == renter['location_id']
        ]['provider_id']

    available_items = location_items[location_items['provider_id'].isin(provider_ids)]
    available_items = available_items.sample(frac=1, random_state=42)

    renter_booking_count = 0
    MAX_BOOKINGS_PER_RENTER = random.randint(4, 13)

    for _, item in available_items.iterrows():
        if renter_booking_count >= MAX_BOOKINGS_PER_RENTER:
            break

        item_id = item['item_id']

        # Decide booking type: 25% short (under 24 hours), 75% long
        if random.random() < 0.25:
            duration = timedelta(hours=random.uniform(1, 23))
        else:
            duration = timedelta(days=random.randint(2, 10))

        start, end = get_non_overlapping_time(item_id, duration)

        if start and end:
            bookings.append({
                'booking_id': booking_id,
                'user_id': renter['user_id'],
                'item_id': item_id,
                'provider_id': item['provider_id'],
                'start_date': start,
                'end_date': end
            })
            booking_id += 1
            renter_booking_count += 1

# Final DataFrame
bookings = pd.DataFrame(bookings)

# %%
bookings['duration'] = bookings['end_date'] - bookings['start_date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
bookingss[bookingss['start_date'] == bookingss['end_date']]
# Out:
#         booking_id  user_id     item_id  provider_id  start_date    end_date
# 1                2    28238  ITEM027903        10340  2024-11-01  2024-11-01
# 5                6    28238  ITEM028402        10379  2025-04-07  2025-04-07
# 6                7    28238  ITEM004247        10296  2025-02-02  2025-02-02
# 10              11    28238  ITEM000849        10295  2025-04-05  2025-04-05
# 13              14    20415  ITEM006786         9626  2024-11-11  2024-11-11
# ...            ...      ...         ...          ...         ...         ...
# 179118      179119    21199  ITEM029235         8487  2024-10-25  2024-10-25
# 179119      179120    21199  ITEM028358         8406  2024-10-23  2024-10-23
# 179120      179121    12963  ITEM005557         3840  2024-10-23  2024-10-23
# 179121      179122    12963  ITEM012666         3891  2025-03-18  2025-03-18
# 179123      179124    12963  ITEM039118         3767  2024-12-24  2024-12-24
#
# [39489 rows x 6 columns]

# %%
bookingss = bookings.copy()

# %%
bookingss['end_date'] = pd.to_datetime(bookingss['end_date']).dt.date
# Out:
# C:\Users\ruhi0\AppData\Local\Temp\ipykernel_20040\945653825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bookingss['end_date'] = pd.to_datetime(bookingss['end_date']).dt.date
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:726, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: offset must be a timedelta strictly between -timedelta(hours=24) and timedelta(hours=24).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[332], line 1
# ----> 1 bookingss['end_date'] = pd.to_datetime(bookingss['end_date']).dt.date
#
# ...

# %%
bookingss
# Out:
#         booking_id  user_id     item_id  provider_id        start_date  \
# 0                1    28238  ITEM007287        10331  2024-12-05 04-44
# 1                2    28238  ITEM027903        10340  2024-11-01 12-44
# 2                3    28238  ITEM025385        10380  2025-03-12 10-44
# 3                4    28238  ITEM005249        10385  2025-02-28 08-44
# 4                5    28238  ITEM039651        10402  2024-12-11 12-44
# ...            ...      ...         ...          ...               ...
# 179140      179141    20744  ITEM038610        11260  2024-11-09 08-44
# 179141      179142    20744  ITEM017730        11294  2025-03-23 23-44
# 179142      179143    20744  ITEM033514        11342  2025-02-21 16-44
# 179143      179144    20744  ITEM031351        11270  2025-03-29 10-44
# 179144      179145    20744  ITEM034079        11325  2025-03-20 07-44
#
#                 end_date               duration
# 0       2024-12-07 04-44        2 days 00:00:00
# ...

# %%
bookings
# Out:
#         booking_id  user_id     item_id  provider_id        start_date  \
# 0                1    28238  ITEM007287        10331  2024-12-05 04-44
# 1                2    28238  ITEM027903        10340  2024-11-01 12-44
# 2                3    28238  ITEM025385        10380  2025-03-12 10-44
# 3                4    28238  ITEM005249        10385  2025-02-28 08-44
# 4                5    28238  ITEM039651        10402  2024-12-11 12-44
# ...            ...      ...         ...          ...               ...
# 179140      179141    20744  ITEM038610        11260  2024-11-09 08-44
# 179141      179142    20744  ITEM017730        11294  2025-03-23 23-44
# 179142      179143    20744  ITEM033514        11342  2025-02-21 16-44
# 179143      179144    20744  ITEM031351        11270  2025-03-29 10-44
# 179144      179145    20744  ITEM034079        11325  2025-03-20 07-44
#
#                 end_date               duration
# 0       2024-12-07 04-44        2 days 00:00:00
# ...

# %%
bookings['user_id'].nunique()
# Out:
# 21044

# %%
items_per_date = bookings.groupby("start_date")["item_id"].count().reset_index()
items_per_date = items_per_date.rename(columns={"item_id": "items_rented"})
# print(items_per_date)
# print()

# %%
a = bookings[bookings['start_date']== '2025-04-08 11:44:37.345396']

# %%
a['item_id'].nunique()
# Out:
# 0

# %%
bookings['start_date'] = pd.to_datetime(bookings['start_date']).dt.strftime("%Y-%m-%d %H:%M")
bookings['end_date'] = pd.to_datetime(bookings['end_date']).dt.strftime("%Y-%m-%d %H:%M")
# Out:
# C:\Users\ruhi0\AppData\Local\Temp\ipykernel_20040\2017197347.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bookings['start_date'] = pd.to_datetime(bookings['start_date']).dt.strftime("%Y-%m-%d %H:%M")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:726, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: offset must be a timedelta strictly between -timedelta(hours=24) and timedelta(hours=24).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[346], line 1
# ----> 1 bookings['start_date'] = pd.to_datetime(bookings['start_date']).dt.strftime("%Y-%m-%d %H:%M")
# ...

# %%
bookings
# Out:
#         booking_id  user_id     item_id  provider_id        start_date  \
# 0                1    28238  ITEM007287        10331  2024-12-05 04-44
# 1                2    28238  ITEM027903        10340  2024-11-01 12-44
# 2                3    28238  ITEM025385        10380  2025-03-12 10-44
# 3                4    28238  ITEM005249        10385  2025-02-28 08-44
# 4                5    28238  ITEM039651        10402  2024-12-11 12-44
# ...            ...      ...         ...          ...               ...
# 179140      179141    20744  ITEM038610        11260  2024-11-09 08-44
# 179141      179142    20744  ITEM017730        11294  2025-03-23 23-44
# 179142      179143    20744  ITEM033514        11342  2025-02-21 16-44
# 179143      179144    20744  ITEM031351        11270  2025-03-29 10-44
# 179144      179145    20744  ITEM034079        11325  2025-03-20 07-44
#
#                 end_date               duration
# 0       2024-12-07 04-44        2 days 00:00:00
# ...

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179145 entries, 0 to 179144
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   booking_id   179145 non-null  int64
#  1   user_id      179145 non-null  int64
#  2   item_id      179145 non-null  object
#  3   provider_id  179145 non-null  int64
#  4   start_date   179145 non-null  object
#  5   end_date     179145 non-null  object
#  6   duration     179145 non-null  timedelta64[ns]
# dtypes: int64(3), object(3), timedelta64[ns](1)
# memory usage: 9.6+ MB

# %%
bookings['start_date'] = pd.to_datetime(bookings['start_date'])
bookings['end_date'] = pd.to_datetime(bookings['end_date'])

# Calculate duration in days
bookings['duration_days'] = (bookings['end_date'] - bookings['start_date']).dt.days

# Optional: Calculate duration in hours too
bookings['duration_hours'] = (bookings['end_date'] - bookings['start_date']).dt.total_seconds() / 3600
# Out:
# C:\Users\ruhi0\AppData\Local\Temp\ipykernel_20040\2351301196.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bookings['start_date'] = pd.to_datetime(bookings['start_date'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:726, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: offset must be a timedelta strictly between -timedelta(hours=24) and timedelta(hours=24).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[352], line 1
# ----> 1 bookings['start_date'] = pd.to_datetime(bookings['start_date'])
#       2 bookings['end_date'] = pd.to_datetime(bookings['end_date'])
# ...

# %%
Hetvi = pd.read_csv("Hetvi_bookings.csv")
Hetvi
# Out:
#        booking_id  user_id     item_id booking_date         rental_start  \
# 0               1      677  ITEM017890   2022-04-03  2022-04-04 04:00:00
# 1               2     9491  ITEM035092   2023-12-25  2023-12-25 18:00:00
# 2               3    17501  ITEM006147   2024-06-04  2024-06-05 15:00:00
# 3               4    13099  ITEM009734   2024-10-05  2024-10-05 23:00:00
# 4               5    23303  ITEM000286   2022-05-13  2022-05-13 11:00:00
# ...           ...      ...         ...          ...                  ...
# 59995       59996    25419  ITEM030142   2022-11-23  2022-11-24 23:00:00
# 59996       59997    22589  ITEM030604   2023-04-11  2023-04-11 13:00:00
# 59997       59998    18632  ITEM039321   2024-01-28  2024-01-28 18:00:00
# 59998       59999     9274  ITEM000503   2024-05-01  2024-05-01 07:00:00
# 59999       60000    21639  ITEM021174   2023-08-18  2023-08-19 23:00:00
#
#                 return_end  rental_duration_hours
# ...

# %%
Hetvi[Hetvi['user_id'] == 16766]
# Out:
#        booking_id  user_id     item_id booking_date         rental_start  \
# 10390       10391    16766  ITEM006471   2023-02-05  2023-02-05 10:00:00
# 12799       12800    16766  ITEM016704   2023-02-22  2023-02-22 04:00:00
# 13305       13306    16766  ITEM027187   2023-02-26  2023-02-26 02:00:00
# 14637       14638    16766  ITEM019886   2023-02-07  2023-02-08 09:00:00
# 21782       21783    16766  ITEM002413   2023-02-24  2023-02-24 16:00:00
# 32634       32635    16766  ITEM010346   2023-02-09  2023-02-10 05:00:00
# 33556       33557    16766  ITEM039371   2023-02-21  2023-02-21 15:00:00
# 48717       48718    16766  ITEM005854   2023-02-14  2023-02-15 19:00:00
# 49391       49392    16766  ITEM032496   2023-02-21  2023-02-21 11:00:00
# 51898       51899    16766  ITEM025637   2023-02-28  2023-02-28 19:00:00
# 52244       52245    16766  ITEM015813   2023-02-14  2023-02-15 16:00:00
# 56973       56974    16766  ITEM014585   2023-02-15  2023-02-15 21:00:00
#
# ...

# %%
Hetvi['user_id'].value_counts()
# Out:
# user_id
# 16766    12
# 17720    11
# 782      11
# 2489     11
# 1456     11
#          ..
# 29192     1
# 27312     1
# 21728     1
# 7949      1
# 14334     1
# Name: count, Length: 19715, dtype: int64

# %%
df_Final_items
# Out:
#                   category          subcategory     item_id  provider_id  \
# 0                    Bikes          Motorcycles  ITEM000001         5326
# 1      Commercial Vehicles  Commercial Vehicles  ITEM000002        10905
# 2                  Mobiles        Mobile Phones  ITEM000003         4676
# 3                    Bikes             Bicycles  ITEM000004         2939
# 4                    Bikes             Bicycles  ITEM000005         2649
# ...                    ...                  ...         ...          ...
# 39995                 Cars                 Cars  ITEM039996         1923
# 39996                 Cars                 Cars  ITEM039997         5410
# 39997                 Cars                 Cars  ITEM039998         4348
# 39998  Commercial Vehicles  Commercial Vehicles  ITEM039999        14445
# 39999              Fashion                  Men  ITEM040000         5677
#
#                                       title  \
# 0      Harley-Davidson Street Glide Special
# ...

# %%
merged_H_I = pd.merge(Hetvi,df_Final_items, on="item_id", how= "inner")

# %%
merged_H_I['rental_start'].value_counts(ascending=False)
# Out:
# rental_start
# 2022-05-02 10:00:00    11
# 2024-11-20 21:00:00    10
# 2022-10-25 11:00:00    10
# 2023-05-10 14:00:00    10
# 2024-06-30 08:00:00    10
#                        ..
# 2022-03-02 23:00:00     1
# 2023-08-26 06:00:00     1
# 2022-10-12 02:00:00     1
# 2024-03-02 04:00:00     1
# 2022-07-06 14:00:00     1
# Name: count, Length: 23887, dtype: int64

# %%
merged_H_I.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   booking_id             60000 non-null  int64
#  1   user_id                60000 non-null  int64
#  2   item_id                60000 non-null  object
#  3   booking_date           60000 non-null  object
#  4   rental_start           60000 non-null  object
#  5   return_end             60000 non-null  object
#  6   rental_duration_hours  60000 non-null  float64
#  7   category               60000 non-null  object
#  8   subcategory            60000 non-null  object
#  9   provider_id            60000 non-null  int64
#  10  title                  60000 non-null  object
#  11  description            60000 non-null  object
#  12  price_per_day          60000 non-null  float64
#  13  location_id            60000 non-null  int64
# ...

# %%
merged_H_I[merged_H_I['user_id'] == 20602]
# Out:
#        booking_id  user_id     item_id booking_date         rental_start  \
# 16816       16817    20602  ITEM020283   2025-02-14  2025-02-15 09:00:00
# 38709       38710    20602  ITEM001031   2025-02-05  2025-02-06 06:00:00
# 56488       56489    20602  ITEM018703   2025-02-13  2025-02-14 01:00:00
#
#                 return_end  rental_duration_hours          category  \
# 16816  2025-02-21 09:00:00                  144.0           Fashion
# 38709  2025-02-06 12:00:00                    6.0  Books and Sports
# 56488  2025-02-14 05:00:00                    4.0           Fashion
#
#          subcategory  provider_id                            title  \
# 16816           Kids        11942  LEGO Classic Creative Brick Box
# 38709  Gym & Fitness        12002  PowerBlock Sport Kettlebell Set
# 56488          Women        11975   Laura Ashley Floral Maxi Dress
#
#                                              description  price_per_day  \
# ...

# %%
df.columns
# Out:
# Index(['user_id', 'name', 'gender', 'age', 'email', 'phone_number',
#        'location_id', 'preferred_services', 'preferred_time_slots',
#        'booking_history_count', 'cancellation_rate', 'average_rating_given',
#        'wallet_balance', 'subscription_status', 'feedback_score',
#        'App_Logins_Per_Month', 'Browsing_History_Depth',
#        'Search_Queries_Performed', 'Click-Through-Rate (CTR)',
#        'Referral_Usage', 'Social_Media_Engagement',
#        'Time_Spent_on_Platform (min)', 'Feedback_Score',
#        'Negative_Reviews_Count', 'Complaints_Raised', 'Issue_Resolution_Time',
#        'Customer_Support_Contacts', 'Booking_Frequency_Change',
#        'Spend_Change_Rate', 'Unsubscribed_Notifications',
#        'Downgrade_Service_Usage', 'Churn_Risk_Score', 'Churn_Label'],
#       dtype='object')
